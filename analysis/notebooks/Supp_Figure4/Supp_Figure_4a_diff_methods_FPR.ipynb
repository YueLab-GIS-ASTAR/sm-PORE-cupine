# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
## 1. Supp_Figure_4a ---  ---

# %%
df = pd.read_csv("/home/han/proj_het_AC/rerun_analysis/0_Manuscript_codes_submission_20250723/Supp_Fig4/Data/evaluation_MRPS21_WT_zarringhalam_ensemble-errors.txt",
                 names=["simulation", "method", "length", "depth", "mod_rate", 
                        "freq_code", "similarity", "cluster", "rep", "fpr", "acc", "fms", "ari", "ami"])

# %%
fig, ax = plt.subplots(2, 4, figsize=(20, 8), sharex=True, sharey=True)

for j, method in enumerate(["BMM", "dreem", "kmeans", "spectral"]):
    for no, depth in enumerate([1000, 10000]):

        df_subset = df[(df.depth == depth) & (df.method == method)]
        sns.boxplot(data=df_subset, x="mod_rate", y="acc", hue="fpr", ax=ax[no,j])
        
        ax[no,j].set_xlabel("")
        ax[no,j].set_ylabel("")
        ax[no,j].set_title("Method = %s | Depth = %s" % (method, depth))
        ax[no,j].legend(loc="lower right", fontsize="medium")
        ax[no,j].axhline(0.8, linewidth=0.5, linestyle="--", color="black", zorder=-10)
    #ax[no].set_ylim(0.45, 0.9)

for i in range(2):
    ax[i,0].set_ylabel("Accuracy")
for i in range(3):
    ax[-1,i].set_xlabel("Modification Rate")

dir_out = '/home/han/proj_het_AC/rerun_analysis/0_Manuscript_codes_submission_20250723/Supp_Fig4/Data/'
fig.savefig(dir_out+'Supp_Figure_4a_cluster_method_compare.pdf',bbox_inches='tight')   # reference human+yeast
