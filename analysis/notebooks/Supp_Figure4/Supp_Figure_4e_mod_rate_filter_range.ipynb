# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

# %%
## 1. Supp_Figure_4e ---  ---

# %%
dir_out = "/home/han/proj_het_AC/rerun_analysis/0_Manuscript_codes_submission_20250723/Supp_Fig4/Data/"
df_subset_mm2_dtw = pd.read_csv(dir_out+'summary_mod_rate_mm2_vs_DTW.txt',sep="\t")
df_subset_mm2_dtw_groupby = df_subset_mm2_dtw.groupby(["gene", "category"]).mean().reset_index()


df_subset_mm2_dtw['category_2'] = 'sm-PORE-cupine'
df_subset_mm2_dtw_groupby = df_subset_mm2_dtw.groupby(["gene", "category_2"]).mean().reset_index()

fig, ax = plt.subplots(1, 1, figsize=(3, 4), dpi=300)
sns.violinplot(x="category_2", y="modrate", data=df_subset_mm2_dtw_groupby, ax=ax, linewidth=1.5)
ax.set_title("Overall modrate: sm-PORE-cupine")
ax.set_xticks([0, 1])
ax.set_xlabel(None)
ax.set_ylabel("ModRate (%)\n(By Transcript)")

dir_out = '/home/han/proj_het_AC/rerun_analysis/0_Manuscript_codes_submission_20250723/Supp_Fig4/Data/'
fig.savefig(dir_out+'Supp_Figure_4e_mod_rate_range_filter.pdf',bbox_inches='tight')
# Out:
# /tmp/ipykernel_5006/3394162980.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_subset_mm2_dtw_groupby = df_subset_mm2_dtw.groupby(["gene", "category_2"]).mean().reset_index()
